# %% [markdown]
# ## Here is the code to get the paper citations

# %%
import bs4 as bs
import urllib.request
import re as re
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#     def get_full_text(self):
#         self.html = urllib.request.urlopen(self.paper_url)# grab html
#         self.soup = bs.BeautifulSoup(self.html,'lxml')# trun pretty 
#         ## extract
#         self.citations = self.soup.find_all('div', attrs={'class':'References'})
#         self.cite_flag = True;
#         if self.citations is None:
#             print('cant get citations for ',self.paper_url) 
#         elif not self.citations: # NN
#             self.citations = self.soup.find('ol', {'class':'references'}).select('li[id]') # get citations
#             if self.citations is None:
#                 print('cant get citations for ',self.paper_url) 
#             elif not a.citations:
#                 print('cant get citations for ',self.paper_url)

# %%
# links_output = []
# for link in a.soup.find_all('a'):
#     links_output.append(link.get('href'))
    
# for i in range(0,len(links_output)): 
#     if links_output[i] is None:
#         continue
#     else:
#         if '.full' in links_output[i]:
#             if 'http:' in links_output[i]:
#                 master_link = links_output[i]
#                 break

# %%
#   self.html = urllib.request.urlopen(self.paper_url)# grab html
#         self.soup = bs.BeautifulSoup(self.html,'lxml')# trun pretty 
#         ## extract
#         ## auto detect journal
#         if "Nature" in self.soup.title.get_text():
#             print('Nature Journal')
#             self.journal = 'Nature'
#             self.citations = self.soup.find('ol', {'class':'references'}).select('li[id]')
            
#             counter = 0
#             prefix = ''#'http://dx.doi.org/'
#             links_output = []
#             for i in range(len(self.citations[0:])):
#                 if self.citations[i].a is None: # if link doesnt exist 
#                     counter = counter + 1
#                     print(i, 'cant find link')
#                 elif len(self.citations[i].a['href']) > 90: # if the link is really long 
#                     print(i, 'long link')
# #                     links_output.append(re.sub("http://dx.doi.org/", '' ,self.citations[i].a['href']))
#                 elif 'http://dx.doi.org/' in self.citations[i].a['href']: # normal
#                     links_output.append(re.sub("http://dx.doi.org/", '' ,self.citations[i].a['href']))
#                 else: # if its short add prefix
#                     links_output.append(re.sub("/doifinder/", '' ,self.citations[i].a['href']))
                    
#             ## save em to class
#             self.links_output = links_output
#             self.missing_links = counter
#             if len(a.links_output) < 1:
#                 counter = 0
#                 for link in self.citations:
#                     for morelinks in link.find_all('a',href = True):
#                         counter = counter + 1
#                         print(counter, morelinks['href'])
#                         if 'http://dx.doi.org/' in morelinks['href']: # normal
#                             links_output.append(re.sub("http://dx.doi.org/", '' ,morelinks['href']))
                        
#             self.random_ten = np.random.choice(self.links_output,size = 10)
            
#         ## commented out for simplicity
#         elif "ScienceDirect" in self.soup.title.get_text(): 
#             print('ScienceDirect',self.soup.title.get_text())
            
#             prefix = 'https://api.elsevier.com/content/abstract/doi/'
#             suffix = '?apiKey=40acd4c83833cb8ead38b50834823fd9&view=REF'
#             doi = self.paper_url

#             self.link = prefix+doi+suffix
#             self.html = urllib.request.urlopen(self.link)# grab html
#             self.soup = bs.BeautifulSoup(self.html,'xml')# trun pretty 

#             self.citations =[]
#             for doi in self.soup.find_all('doi'):
#                 self.citations.append(doi.contents[0])

#             self.random_ten = np.random.choice(self.citations,size = 10)
            
#         elif "Science" in self.soup.title.get_text(): # science
#             print('Science',self.soup.title.get_text())
            
#             print('getting full text','Science Journal')
#             self.journal = 'Science'
#             self.soup = bs.BeautifulSoup(self.html,'lxml')#        
#             self.citations = self.soup.find_all('div', attrs={'class':'References'})
#             if self.citations is None:
#                 print('actually abstract getting really')
#                 links_output = []
#                 for link in self.soup.find_all('a'):
#                     links_output.append(link.get('href'))

#                 for i in range(0,len(links_output)): 
#                     if links_output[i] is None:
#                         continue
#                     else:
#                         if '.full' in links_output[i]:
#                             if 'http:' in links_output[i]:
#                                 self.master_link = links_output[i]
#                                 break
#                 self.html = urllib.request.urlopen(self.master_link)# grab html
#                 self.soup = bs.BeautifulSoup(self.html,'lxml')#        
#                 self.citations = self.soup.find_all('div', attrs={'class':'References'})
#                 self.random_ten = np.random.choice(self.citations,size = 10)
#             else:
#                 print(self.citations)
# #                 self.random_ten = np.random.choice(self.citations,size = 10)
#         else:
#             print(self.soup.title.get_text(),'unsupported journal')

# %%
# def get_links(self):    
#         ## get links
#         counter = 0
#         prefix = ''#'http://dx.doi.org/'
#         links_output = [] # create output 
#         if self.cite_flag == True:
#             for i in range(len(self.citations[0:])):
#                 if len(self.citations[i].find_all('a')) == 4:
#                     links_output.append(self.citations[i].find_all('a')[3]['href'])
#                 elif len(self.citations[i].find_all('a')) < 2 :
#                     counter = counter + 1
#                     print(i,'cant find link')
#                 elif 'http://dx.doi.org/' in self.citations[i].find_all('a')[1]['href']:
#                     links_output.append(self.citations[i].find_all('a')[1]['href'])
#                 else:
#                     counter = counter + 1
#                     print(i,'cant find link')

#         else: ## v1 
#             for i in range(len(self.citations[0:])):
#                 if self.citations[i].a is None: # if link doesnt exist 
#                     counter = counter + 1
#                     print(i, 'cant find link')
#                 elif len(self.citations[i].a['href']) > 120: # if the link is really long 
#                     links_output.append(re.sub("http://dx.doi.org/", '' ,self.citations[i].a['href']))
#                 elif 'http://dx.doi.org/' in self.citations[i].a['href']: # normal
#                     links_output.append(self.citations[i].a['href'])
#                 else: # if its short add prefix
#                     links_output.append(prefix + re.sub("/doifinder/", '' ,self.citations[i].a['href']))
                    
#         ## save em to class
#         self.links_output = links_output
#         self.missing_links = counter
#         self.random_ten = np.random.choice(self.links_output,size = 10)

# %%
# need to get j neuroscience to work better
class nerdy:
    def __init__(self, paper_url):
        if 'http://dx' in paper_url:
            print('a')
            self.paper_url = paper_url
        elif 'http' in paper_url:
            print('b')
            self.paper_url = paper_url
        else:
            print('c')
            self.paper_url = 'http://dx.doi.org/' + paper_url
                        
    def get_full_text(self,layer):
        
        self.layer = layer
        
        prefix = 'https://api.elsevier.com/content/abstract/doi/'
        suffix = '?apiKey=40acd4c83833cb8ead38b50834823fd9&view=REF'
        doi = self.paper_url.replace("http://dx.doi.org/","")
        self.link = prefix+doi+suffix
        
        # added error handeling
        req = urllib.request.Request(self.link)
        try: urllib.request.urlopen(req)
        except urllib.error.URLError as e:
            print('link ' + e.reason)
        # proceed notmally     
        self.html = urllib.request.urlopen(self.link)# grab html
        self.soup = bs.BeautifulSoup(self.html,'xml')# trun pretty 
        
        self.citations =[]
        self.authors = []
        self.journal = []

        for reference in self.soup.find_all('reference'):
            if reference.doi is None: # remove any articles that dont have a doi
                print('skip')
                continue
            else:
                self.citations.append(reference.doi.contents[0])
                self.authors.append(reference.surname.contents[0])
                self.journal.append(reference.sourcetitle.contents[0])
                
        self.article =  pd.DataFrame({"authors": self.authors,"journal": self.journal, \
                         "DOI": self.citations})  # put in dframe
#         self.article = self.article.loc[self.article['DOI'] != 'None'] 
        self.random_ten = self.article.sample(10)
        
        if self.layer == 0:
            self.random_ten['number'] = np.arange(0.1,1.1,0.1)
        else:
            self.random_ten['number'] = np.arange(0.1+self.layer,1.1+self.layer,0.1)
            
        self.random_ten['combined'] = self.random_ten[['authors', 'journal','DOI']].apply(lambda x: '. '.join(x), axis=1)
        self.random_ten = self.random_ten.reset_index(drop = True)
        
        if self.layer == 0: # getting zero level things
            self.zero_link = prefix+doi+'?apiKey=40acd4c83833cb8ead38b50834823fd9&'+'&view=META'
            self.zero_html = urllib.request.urlopen(self.zero_link)# grab html
            self.zero_soup = bs.BeautifulSoup(self.zero_html,'xml')# trun pretty 
            name = self.zero_soup.surname.contents[0]
            pub = self.zero_soup.publicationName.contents[0]
            self.random_ten.loc[-1]=[doi,name,pub,'0','.'.join((name,pub,doi))]
            self.random_ten.index = self.random_ten.index + 1  # shifting index
            self.random_ten = self.random_ten.sort() 
            self.random_ten = pd.DataFrame(self.random_ten)
            
#         self.candace.append(self.random_ten)
        
        return(self.random_ten)
        
                
        
    def find_childrens_children(self):
        child_list = self.random_ten['DOI']
        
        for idx,child in enumerate(range(1,len(child_list))):
            a = self.nerdy(child)
            child_child = self.get_full_text(child,idx)
            print('working on article ', child, 'citations:')
#             self.article.append(child_child)        
#         # append to list     
#         self.citations =[]
#         for doi in self.soup.find_all('doi'):
#             self.citations.append(doi.contents[0])

#         self.random_ten = np.random.choice(self.citations,size = 10)

# %%
a = nerdy('10.1038/nrn3338')
a.get_full_text(0)
# Out:
# c
# skip
# skip
# skip
# skip
# skip
# skip
# /home/jecd/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:65: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#                                                   DOI     authors  \
# 0                                     10.1038/nrn3338   Ranganath
# 1                                   10.1002/cne.10243     Lavenex
# 2              10.1016/j.neuropsychologia.2003.07.006   Ranganath
# 3                               10.1073/pnas.98.2.676     Raichle
# 4                        10.1016/j.neuron.2005.07.013   Gonsalves
# 5                                  10.1002/hipo.20852   Ranganath
# 6                               10.1002/cne.902250105      Mufson
# 7                               10.1002/cne.903500402      Suzuki
# 8                                   10.1002/cne.10883   Kobayashi
# 9                                     10.1038/nrn3008     Kravitz
# 10  10.1002/(SICI)1096-9861(19961125)375:4<552::AI...  Stefanacci
#
#                                               journal number  \
# 0                         Nature Reviews Neuroscience      0
# 1                    Journal of Comparative Neurology    0.1
# 2                                    Neuropsychologia    0.2
# 3   Proceedings of the National Academy of Science...    0.3
# 4                                              Neuron    0.4
# 5                                         Hippocampus    0.5
# 6                    Journal of Comparative Neurology    0.6
# 7                    Journal of Comparative Neurology    0.7
# 8                    Journal of Comparative Neurology    0.8
# 9                         Nature Reviews Neuroscience    0.9
# 10                   Journal of Comparative Neurology      1
#
#                                              combined
# 0   Ranganath.Nature Reviews Neuroscience.10.1038/...
# 1   Lavenex. Journal of Comparative Neurology. 10....
# 2   Ranganath. Neuropsychologia. 10.1016/j.neurops...
# 3   Raichle. Proceedings of the National Academy o...
# 4     Gonsalves. Neuron. 10.1016/j.neuron.2005.07.013
# 5          Ranganath. Hippocampus. 10.1002/hipo.20852
# 6   Mufson. Journal of Comparative Neurology. 10.1...
# 7   Suzuki. Journal of Comparative Neurology. 10.1...
# 8   Kobayashi. Journal of Comparative Neurology. 1...
# 9   Kravitz. Nature Reviews Neuroscience. 10.1038/...
# 10  Stefanacci. Journal of Comparative Neurology. ...

# %%
a.find_childrens_children()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-9bbd53bc5457> in <module>()
# ----> 1 a.find_childrens_children()
#
# <ipython-input-41-7993b534e16e> in find_childrens_children(self)
#      76
#      77         for idx,child in enumerate(range(1,len(child_list))):
# ---> 78             child_child = self.get_full_text(child,idx)
#      79             print('working on article ', child, 'citations:')
#      80             self.article.append(child_child)
#
# TypeError: get_full_text() takes 2 positional arguments but 3 were given

# %%
a.article
# Out:
#                                                   DOI        authors  \
# 0                                    10.1038/35049064          Brown
# 1              10.1146/annurev.neuro.30.051606.094328     Eichenbaum
# 2                              10.1098/rstb.1997.0132        Mishkin
# 3                                     10.1038/nrn2733           Vann
# 4                            10.1093/brain/110.6.1631     Valenstein
# 5   10.1002/1098-1063(2000)10:4<398::AID-HIPO6>3.0...         Witter
# 6                     10.1016/j.neubiorev.2011.09.005       Aggleton
# 7                                  10.1002/hipo.20314         Furtak
# 8                                  10.1002/hipo.22024       Aggleton
# 9   10.1002/(SICI)1096-9861(19961125)375:4<552::AI...     Stefanacci
# 10                              10.1152/jn.00077.2008           Kahn
# 11                     10.1523/JNEUROSCI.3711-11.2012          Libby
# 12                                  10.1002/cne.10883      Kobayashi
# 13                                  10.1002/cne.21346      Kobayashi
# 14                              10.1002/cne.903500402         Suzuki
# 15                                  10.1002/cne.20079        Lavenex
# 16                                  10.1002/cne.10243        Lavenex
# 17                                  10.1002/cne.20796          Kondo
# 18                                    10.1038/nrn3008        Kravitz
# 19                              10.1002/cne.902250105         Mufson
# 20                              10.1073/pnas.98.2.676        Raichle
# 21                       10.1016/j.neuron.2010.02.005  Andrews-Hanna
# 22                   10.1016/j.neuroimage.2007.12.043        Höistad
# 23  10.1002/1098-1063(2001)11:1<61::AID-HIPO1021>3...         Baxter
# 24                     10.1523/JNEUROSCI.3763-03.2004        Nemanic
# 25                                 10.1002/hipo.20852      Ranganath
# 26                                 10.1002/hipo.20853       Montaldi
# 27                            10.1073/pnas.0705273104         Bowles
# 28                      10.1016/S0028-3908(98)00030-6          Xiang
# 29                                 10.1002/hipo.10117         Henson
# 30                                 10.1002/hipo.20178       Montaldi
# 31                       10.1016/j.neuron.2005.07.013      Gonsalves
# 32             10.1016/j.neuropsychologia.2003.07.006      Ranganath
# 33                            10.1073/pnas.0337195100        Davachi
#
#                                               journal
# 0                         Nature Reviews Neuroscience
# 1                       Annual Review of Neuroscience
# 2   Philosophical Transactions of the Royal Societ...
# 3                         Nature Reviews Neuroscience
# 4                                               Brain
# 5                                         Hippocampus
# 6              Neuroscience and Biobehavioral Reviews
# 7                                         Hippocampus
# 8                                         Hippocampus
# 9                    Journal of Comparative Neurology
# 10                         Journal of Neurophysiology
# 11                            Journal of Neuroscience
# 12                   Journal of Comparative Neurology
# 13                   Journal of Comparative Neurology
# 14                   Journal of Comparative Neurology
# 15                   Journal of Comparative Neurology
# 16                   Journal of Comparative Neurology
# 17                   Journal of Comparative Neurology
# 18                        Nature Reviews Neuroscience
# 19                   Journal of Comparative Neurology
# 20  Proceedings of the National Academy of Science...
# 21                                             Neuron
# 22                                         NeuroImage
# 23                                        Hippocampus
# 24                            Journal of Neuroscience
# 25                                        Hippocampus
# 26                                        Hippocampus
# 27  Proceedings of the National Academy of Science...
# 28                                  Neuropharmacology
# 29                                        Hippocampus
# 30                                        Hippocampus
# 31                                             Neuron
# 32                                   Neuropsychologia
# 33  Proceedings of the National Academy of Science...

# %%
for reference in a.soup.find_all('reference'):
    if reference.doi is None:
        print('meow')
        continue
    else:
        print(reference.doi.contents[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-66b2175b0b2f> in <module>()
# ----> 1 for reference in a.soup.find_all('reference'):
#       2     if reference.doi is None:
#       3         print('meow')
#       4         continue
#       5     else:
#
# NameError: name 'a' is not defined

# %%
a.article
a.citations

# %%
a.paper_url
